# %%
from pLaplace_2D import test_runner_2D

problem_setting = {"p": 3}  # source term, constant 10

# %% [markdown]
# # Results

# %%
sizes = [1,2,3,4,5,6,7,8,9]
all_solvers = []

all_solvers.append({"val_grad": "numpy",
                    "hess": "none",
                    "minimizer": ["scipy_L-BFGS-B"],
                    "solver_type": "amg",
                    "initial_guess": "zero",
                    "problem_setting": problem_setting,
                    "sizes": sizes})
all_solvers.append({"val_grad": "numba",
                    "hess": "none",
                    "minimizer": ["scipy_L-BFGS-B"],
                    "solver_type": "amg",
                    "initial_guess": "zero",
                    "problem_setting": problem_setting,
                    "sizes": sizes})
all_solvers.append({"val_grad": "jax",
                    "hess": "none",
                    "minimizer": ["scipy_L-BFGS-B"],
                    "solver_type": "amg",
                    "initial_guess": "zero",
                    "problem_setting": problem_setting,
                    "sizes": sizes})
all_solvers.append({"val_grad": "numba",
                    "hess": "SFD",
                    "minimizer": ["scipy_Newton-CG_hessp"],
                    "solver_type": "amg",
                    "initial_guess": "zero",
                    "problem_setting": problem_setting,
                    "sizes": sizes})

all_solvers.append({"val_grad": "numba",
                    "hess": "SFD",
                    "minimizer": ["my_trust_region"],
                    "solver_type": "amg",
                    "initial_guess": "rand",
                    "problem_setting": problem_setting,
                    "sizes": sizes})
all_solvers.append({"val_grad": "jax",
                    "hess": "sparse",
                    "minimizer": ["my_trust_region"],
                    "solver_type": "amg",
                    "initial_guess": "rand",
                    "problem_setting": problem_setting,
                    "sizes": sizes})
all_solvers.append({"val_grad": "numba",
                    "hess": "SFD",
                    "minimizer": ["my_newton"],
                    "solver_type": "amg",
                    "initial_guess": "rand",
                    "problem_setting": problem_setting,
                    "sizes": sizes})
all_solvers.append({"val_grad": "jax",
                    "hess": "sparse",
                    "minimizer": ["my_newton"],
                    "solver_type": "amg",
                    "initial_guess": "rand",
                    "problem_setting": problem_setting,
                    "sizes": sizes})
all_solvers.append({"val_grad": "numba",
                    "hess": "SFD",
                    "minimizer": ["my_newton"],
                    "solver_type": "amg",
                    "initial_guess": "laplace",
                    "problem_setting": problem_setting,
                    "sizes": sizes})
all_solvers.append({"val_grad": "jax",
                    "hess": "sparse",
                    "minimizer": ["my_newton"],
                    "solver_type": "amg",
                    "initial_guess": "laplace",
                    "problem_setting": problem_setting,
                    "sizes": sizes})


results = test_runner_2D.test_runner_2D(all_solvers)
iterations_df, f_val_df, compile_df, solve_df, combined_time_df, combined_df, combined_df2 = \
                                test_runner_2D.create_tables(results, display_table="Ipython")
# Out:
# Function value:
#                                               5           33          161     \
# numpy/none/scipy L-BFGS-B/zero/amg        -5.9342512  -7.3411135  -7.7766893
# numba/none/scipy L-BFGS-B/zero/amg        -5.9342512  -7.3411135  -7.7766893
# jax/none/scipy L-BFGS-B/zero/amg          -5.9342512  -7.3411135  -7.7766893
# numba/SFD/scipy Newton-CG hessp/zero/amg  -5.9342512  -7.3411135  -7.7766893
# numba/SFD/my newton/rand/amg              0.001 / 0.006     5  0.001 / 0.010
# jax/sparse/my newton/rand/amg             0.075 / 0.091     6  0.077 / 0.083
# numba/SFD/my newton/laplace/amg           0.001 / 0.003     3  0.001 / 0.008
# jax/sparse/my newton/laplace/amg          0.074 / 0.044     3  0.079 / 0.075
#
# $\mathcal{N}_{dof}$                                   $n=161$        \
# Option                                   iters  time prep/sol iters
# numpy/none/scipy L-BFGS-B/zero/amg          17  0.000 / 0.004    45
# numba/none/scipy L-BFGS-B/zero/amg          17  0.000 / 0.007    45
# jax/none/scipy L-BFGS-B/zero/amg            17  0.065 / 0.003    45
# numba/SFD/scipy Newton-CG hessp/zero/amg    11  0.001 / 0.015    14
# numba/SFD/my trust region/rand/amg           7  0.001 / 0.043     7
# jax/sparse/my trust region/rand/amg          6  0.080 / 0.152     8
# numba/SFD/my newton/rand/amg                 5  0.001 / 0.021     6
# jax/sparse/my newton/rand/amg                5  0.081 / 0.102     6
# numba/SFD/my newton/laplace/amg              4  0.001 / 0.012     4
# jax/sparse/my newton/laplace/amg             4  0.085 / 0.079     4
#
# $\mathcal{N}_{dof}$                             $n=705$             $n=2945$  \
# Option                                    time prep/sol iters  time prep/sol
# numpy/none/scipy L-BFGS-B/zero/amg        0.000 / 0.018    88  0.001 / 0.145
# numba/none/scipy L-BFGS-B/zero/amg        0.001 / 0.019    88  0.001 / 0.087
# jax/none/scipy L-BFGS-B/zero/amg          0.064 / 0.012    88  0.065 / 0.096
# numba/SFD/scipy Newton-CG hessp/zero/amg  0.003 / 0.023    15  0.012 / 0.059
# numba/SFD/my trust region/rand/amg        0.003 / 0.082     9  0.012 / 0.155
# jax/sparse/my trust region/rand/amg       0.083 / 0.207     9  0.098 / 0.327
# numba/SFD/my newton/rand/amg              0.003 / 0.029     6  0.012 / 0.076
# jax/sparse/my newton/rand/amg             0.082 / 0.115     6  0.098 / 0.195
# numba/SFD/my newton/laplace/amg           0.003 / 0.018     4  0.012 / 0.052
# jax/sparse/my newton/laplace/amg          0.084 / 0.075     4  0.097 / 0.137
#
# $\mathcal{N}_{dof}$                                 $n=12033$        \
# Option                                   iters  time prep/sol iters
# numpy/none/scipy L-BFGS-B/zero/amg         201  0.002 / 1.711   426
# numba/none/scipy L-BFGS-B/zero/amg         205  0.003 / 2.997   435
# jax/none/scipy L-BFGS-B/zero/amg           205  0.069 / 0.987   419
# numba/SFD/scipy Newton-CG hessp/zero/amg    15  0.047 / 0.410    15
# numba/SFD/my trust region/rand/amg           9  0.046 / 0.508    10
# jax/sparse/my trust region/rand/amg          9  0.151 / 0.952    10
# numba/SFD/my newton/rand/amg                 7  0.046 / 0.325     8
# jax/sparse/my newton/rand/amg                7  0.150 / 0.478     8
# numba/SFD/my newton/laplace/amg              5  0.048 / 0.180     5
# jax/sparse/my newton/laplace/amg             5  0.154 / 0.282     5
#
# $\mathcal{N}_{dof}$                            $n=48641$        \
# Option                                     time prep/sol iters
# numpy/none/scipy L-BFGS-B/zero/amg        0.008 / 13.092   937
# numba/none/scipy L-BFGS-B/zero/amg        0.011 / 10.471   858
# jax/none/scipy L-BFGS-B/zero/amg           0.081 / 7.573   911
# numba/SFD/scipy Newton-CG hessp/zero/amg   0.212 / 1.358    15
# numba/SFD/my trust region/rand/amg         0.204 / 1.699    11
# jax/sparse/my trust region/rand/amg        0.381 / 2.487    13
# numba/SFD/my newton/rand/amg               0.205 / 1.000     8
# jax/sparse/my newton/rand/amg              0.380 / 1.209     8
# numba/SFD/my newton/laplace/amg            0.203 / 0.542     5
# jax/sparse/my newton/laplace/amg           0.382 / 0.676     5
#
# $\mathcal{N}_{dof}$                            $n=195585$        \
# Option                                      time prep/sol iters
# numpy/none/scipy L-BFGS-B/zero/amg        0.049 / 103.423  1955
# numba/none/scipy L-BFGS-B/zero/amg         0.063 / 53.200  1933
# jax/none/scipy L-BFGS-B/zero/amg           0.143 / 45.986  1978
# numba/SFD/scipy Newton-CG hessp/zero/amg    0.969 / 8.763    15
# numba/SFD/my trust region/rand/amg         0.960 / 11.301    14
# jax/sparse/my trust region/rand/amg        1.645 / 12.161    15
# numba/SFD/my newton/rand/amg                0.963 / 4.801     8
# jax/sparse/my newton/rand/amg               1.628 / 4.610     7
# numba/SFD/my newton/laplace/amg             0.954 / 3.091     6
# jax/sparse/my newton/laplace/amg            1.640 / 3.368     6
#
# $\mathcal{N}_{dof}$                            $n=784385$
# Option                                      time prep/sol iters
# numpy/none/scipy L-BFGS-B/zero/amg        0.284 / 936.276  4167
# numba/none/scipy L-BFGS-B/zero/amg        0.370 / 499.998  4092
# jax/none/scipy L-BFGS-B/zero/amg          0.482 / 410.905  3935
# numba/SFD/scipy Newton-CG hessp/zero/amg   4.326 / 69.356    17
# numba/SFD/my trust region/rand/amg         4.315 / 41.584    11
# jax/sparse/my trust region/rand/amg        7.663 / 43.220    11
# numba/SFD/my newton/rand/amg               4.286 / 26.820     8
# jax/sparse/my newton/rand/amg              6.913 / 28.178     8
# numba/SFD/my newton/laplace/amg            4.342 / 16.197     6
# jax/sparse/my newton/laplace/amg           6.888 / 16.034     6

# %%
print(combined_df2.to_latex(escape=False))
print(compile_df.to_latex(escape=False))
# Out:
# \begin{tabular}{lllllllllllllllllll}
# \toprule
# $|\mathcal{N}_{dof}|$ & \multicolumn{2}{l}{$n=5$} & \multicolumn{2}{l}{$n=33$} & \multicolumn{2}{l}{$n=161$} & \multicolumn{2}{l}{$n=705$} & \multicolumn{2}{l}{$n=2945$} & \multicolumn{2}{l}{$n=12033$} & \multicolumn{2}{l}{$n=48641$} & \multicolumn{2}{l}{$n=195585$} & \multicolumn{2}{l}{$n=784385$} \\
# jax/none/scipy L-BFGS-B/zero/amg         &  0.101 &  0.061 &  0.065 &  0.064 &  0.065 &  0.069 &  0.081 &  0.143 &  0.482 \\
# numba/SFD/scipy Newton-CG hessp/zero/amg &  0.001 &  0.001 &  0.001 &  0.003 &  0.012 &  0.047 &  0.212 &  0.969 &  4.326 \\
# numba/SFD/my trust region/rand/amg       &  0.001 &  0.001 &  0.001 &  0.003 &  0.012 &  0.046 &  0.204 &  0.960 &  4.315 \\
# jax/sparse/my trust region/rand/amg      &  0.779 &  0.077 &  0.080 &  0.083 &  0.098 &  0.151 &  0.381 &  1.645 &  7.663 \\
# numba/SFD/my newton/rand/amg             &  0.001 &  0.001 &  0.001 &  0.003 &  0.012 &  0.046 &  0.205 &  0.963 &  4.286 \\
# jax/sparse/my newton/rand/amg            &  0.075 &  0.077 &  0.081 &  0.082 &  0.098 &  0.150 &  0.380 &  1.628 &  6.913 \\
# numba/SFD/my newton/laplace/amg          &  0.001 &  0.001 &  0.001 &  0.003 &  0.012 &  0.048 &  0.203 &  0.954 &  4.342 \\
# jax/sparse/my newton/laplace/amg         &  0.074 &  0.079 &  0.085 &  0.084 &  0.097 &  0.154 &  0.382 &  1.640 &  6.888 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_2721442/551063152.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(combined_df2.to_latex(escape=False))
# /tmp/ipykernel_2721442/551063152.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(compile_df.to_latex(escape=False))

# %%
sizes = [4,5,6,7,8,9,10]
all_solvers = []

all_solvers.append({"val_grad": "numba",
                    "hess": "SFD",
                    "minimizer": ["my_newton"],
                    "solver_type": "amg",
                    "initial_guess": "zero",
                    "problem_setting": problem_setting,
                    "sizes": sizes})


results = test_runner_2D.test_runner_2D(all_solvers)
iterations_df, f_val_df, compile_df, solve_df, combined_time_df, combined_df, combined_df2 = \
                                test_runner_2D.create_tables(results, display_table="Ipython")
# Out:
# Function value:
#                                  705         2945        12033       48641    \
# numba/SFD/my newton/zero/amg  -7.9050807  -7.9429686  -7.9545636  -7.9582924
#
#                                  195585      784385      3141633
# numba/SFD/my newton/zero/amg  -7.9595563  -7.9600057  -7.9601717
# Time and iters:
# $\mathcal{N}_{dof}$                 $n=705$             $n=2945$        \
# Option                        time prep/sol iters  time prep/sol iters
# numba/SFD/my newton/zero/amg  0.003 / 0.042     8  0.011 / 0.072     7
#
# $\mathcal{N}_{dof}$               $n=12033$            $n=48641$        \
# Option                        time prep/sol iters  time prep/sol iters
# numba/SFD/my newton/zero/amg  0.047 / 0.294     8  0.204 / 0.922     8
#
# $\mathcal{N}_{dof}$              $n=195585$            $n=784385$        \
# Option                        time prep/sol iters   time prep/sol iters
# numba/SFD/my newton/zero/amg  0.981 / 4.649     9  4.309 / 23.487     9
#
# $\mathcal{N}_{dof}$                $n=3141633$
# Option                           time prep/sol iters
# numba/SFD/my newton/zero/amg  18.269 / 134.627    10
