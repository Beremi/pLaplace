# %%
from pLaplace_1D import test_runner_1D

# all possible types of inputs (not all combinations allowed)
_ = ["numpy", "numba", "jax", "none"]  # "val_grad"
_ = ["Laplace", "SFD", "dense", "sparse"]  # "hess"
_ = ["my_newton", "my_trust_region",
     "scipy_trust-exact", "scipy_Newton-CG", "scipy_BFGS", "scipy_L-BFGS-B"]  # "minimizer"
_ = ["zero", "laplace"]  # "initial_guess"

problem_setting = {"p": 3,   # p in pLaplace
                   "a": -1,  # left bound of computational domain
                   "b": 1,   # right bound of computational domain
                   "f": "default"}  # source term, constant 10

sizes = [10, 100, 1000, 10000]

# %% [markdown]
# **-16.865480854231357**

# %% [markdown]
# # Table

# %%
all_solvers = []

all_solvers.append({"val_grad": "numba",
                    "hess": "SFD",
                    "minimizer": ["my_trust_region"],
                    "initial_guess": "zero",
                    "problem_setting": problem_setting,
                    "sizes": sizes})
all_solvers.append({"val_grad": "jax",
                    "hess": "sparse",
                    "minimizer": ["my_trust_region"],
                    "initial_guess": "zero",
                    "problem_setting": problem_setting,
                    "sizes": sizes})
all_solvers.append({"val_grad": "numba",
                    "hess": "Laplace",
                    "minimizer": ["my_newton"],
                    "initial_guess": "zero",
                    "problem_setting": problem_setting,
                    "sizes": sizes})
all_solvers.append({"val_grad": "numba",
                    "hess": "SFD",
                    "minimizer": ["my_newton"],
                    "initial_guess": "laplace",
                    "problem_setting": problem_setting,
                    "sizes": sizes})
all_solvers.append({"val_grad": "jax",
                    "hess": "sparse",
                    "minimizer": ["my_newton"],
                    "initial_guess": "laplace",
                    "problem_setting": problem_setting,
                    "sizes": sizes})

all_solvers.append({"val_grad": "numpy",
                    "hess": "none",
                    "minimizer": ["scipy_L-BFGS-B"],
                    "initial_guess": "zero",
                    "problem_setting": problem_setting,
                    "sizes": sizes})
all_solvers.append({"val_grad": "numba",
                    "hess": "none",
                    "minimizer": ["scipy_L-BFGS-B"],
                    "initial_guess": "zero",
                    "problem_setting": problem_setting,
                    "sizes": sizes})
all_solvers.append({"val_grad": "jax",
                    "hess": "none",
                    "minimizer": ["scipy_L-BFGS-B"],
                    "initial_guess": "zero",
                    "problem_setting": problem_setting,
                    "sizes": sizes})
all_solvers.append({"val_grad": "numba",
                    "hess": "SFD",
                    "minimizer": ["scipy_Newton-CG_hessp"],
                    "initial_guess": "zero",
                    "problem_setting": problem_setting,
                    "sizes": sizes})

results = test_runner_1D.test_runner_1D(all_solvers)
iterations_df, f_val_df, compile_df, solve_df, combined_time_df, combined_df, combined_df2 = test_runner_1D.create_tables(
    results, display_table="Ipython")
# Out:
# Function value:
#                                             10           100          1000   \
# numba/SFD/my trust region/zero        -16.7724671  -16.8644661  -16.8654704
# jax/sparse/my trust region/zero       -16.7724671  -16.8644661  -16.8654704
# numba/Laplace/my newton/zero          -16.7724671  -16.8644660  -16.8654704
# numba/SFD/my newton/laplace           -16.7724671  -16.8644661  -16.8654704
# jax/sparse/my newton/laplace          -16.7724671  -16.8644661  -16.8654704
# numpy/none/scipy L-BFGS-B/zero        -16.7724671  -16.8644661  -16.8654704
# numba/none/scipy L-BFGS-B/zero        -16.7724671  -16.8644661  -16.8654704
# jax/none/scipy L-BFGS-B/zero          -16.7724671  -16.8644661  -16.8654704
# numba/SFD/scipy Newton-CG hessp/zero  -16.7724671  -16.8644661  -16.8654704
#
#                                             10000
# numba/SFD/my trust region/zero        -16.8654807
# jax/sparse/my trust region/zero       -16.8654807
# numba/Laplace/my newton/zero          -16.8654807
# numba/SFD/my newton/laplace           -16.8654807
# jax/sparse/my newton/laplace          -16.8654807
# numpy/none/scipy L-BFGS-B/zero        -16.8654807
# numba/none/scipy L-BFGS-B/zero        -16.8654807
# jax/none/scipy L-BFGS-B/zero          -16.8654807
# numba/SFD/scipy Newton-CG hessp/zero  -16.8654807
# Time and iters:
# $\mathcal{N}_{dof}$                          $n=10$              $n=100$  \
# Option                                time prep/sol iters  time prep/sol
# numba/SFD/my trust region/zero        0.397 / 0.006     9  0.238 / 0.015
# jax/sparse/my trust region/zero       0.094 / 0.016     9  0.103 / 0.093
# numba/Laplace/my newton/zero          0.379 / 0.001    15  0.237 / 0.002
# numba/SFD/my newton/laplace           0.230 / 0.001     4  0.386 / 0.001
# jax/sparse/my newton/laplace          0.093 / 0.001     4  0.102 / 0.003
# numpy/none/scipy L-BFGS-B/zero        0.000 / 0.001    16  0.000 / 0.009
# numba/none/scipy L-BFGS-B/zero        0.235 / 0.000    16  0.387 / 0.004
# jax/none/scipy L-BFGS-B/zero          0.039 / 0.001    16  0.048 / 0.008
# numba/SFD/scipy Newton-CG hessp/zero  0.232 / 0.002    12  0.390 / 0.009
#
# $\mathcal{N}_{dof}$                              $n=1000$        \
# Option                               iters  time prep/sol iters
# numba/SFD/my trust region/zero          18  0.245 / 0.039    26
# jax/sparse/my trust region/zero         48  0.105 / 1.818   487
# numba/Laplace/my newton/zero            37  0.235 / 0.011    63
# numba/SFD/my newton/laplace              5  0.235 / 0.004     8
# jax/sparse/my newton/laplace             5  0.102 / 0.005     6
# numpy/none/scipy L-BFGS-B/zero         319  0.000 / 0.225  3314
# numba/none/scipy L-BFGS-B/zero         267  0.230 / 0.165  3280
# jax/none/scipy L-BFGS-B/zero           272  0.048 / 0.231  3025
# numba/SFD/scipy Newton-CG hessp/zero    19  0.236 / 0.213    19
#
# $\mathcal{N}_{dof}$                        $n=10000$
# Option                                 time prep/sol  iters
# numba/SFD/my trust region/zero         0.253 / 0.977    129
# jax/sparse/my trust region/zero       0.257 / 21.543   1343
# numba/Laplace/my newton/zero           0.239 / 0.073     63
# numba/SFD/my newton/laplace            0.242 / 0.165     41
# jax/sparse/my newton/laplace           0.137 / 0.038      7
# numpy/none/scipy L-BFGS-B/zero        0.000 / 18.809  41504
# numba/none/scipy L-BFGS-B/zero        0.230 / 17.507  41711
# jax/none/scipy L-BFGS-B/zero          0.051 / 26.365  44918
# numba/SFD/scipy Newton-CG hessp/zero  0.246 / 16.843    122

# %%
print(combined_df2.to_latex(escape=False))
print(compile_df.to_latex(escape=False))
# Out:
# \begin{tabular}{lllllllll}
# \toprule
# $|\mathcal{N}_{dof}|$ & \multicolumn{2}{l}{$n=10$} & \multicolumn{2}{l}{$n=100$} & \multicolumn{2}{l}{$n=1000$} & \multicolumn{2}{l}{$n=10000$} \\
# Option &   time & iters &    time & iters &     time & iters &      time &  iters \\
# \midrule
# ('numba', 'SFD', 'my_trust_region', 'zero')       &  0.019 &     9 &   0.046 &    18 &    0.105 &    25 &     2.251 &    102 \\
# ('jax', 'sparse', 'my_trust_region', 'zero')      &  0.052 &     9 &   0.354 &    47 &    6.187 &   485 &    97.956 &   1603 \\
# ('numba', 'Laplace', 'my_newton', 'zero')         &  0.002 &    15 &   0.005 &    37 &    0.032 &    63 &     0.189 &     62 \\
# ('numba', 'SFD', 'my_newton', 'laplace')          &  0.003 &     4 &   0.004 &     5 &    0.013 &     8 &     0.891 &     72 \\
# ('jax', 'sparse', 'my_newton', 'laplace')         &  0.004 &     4 &   0.007 &     5 &    0.017 &     6 &     0.100 &      7 \\
# ('numpy', 'none', 'scipy_L-BFGS-B', 'zero')       &  0.003 &    16 &   0.019 &   259 &    0.854 &  3416 &    75.245 &  39000 \\
# ('numba', 'none', 'scipy_L-BFGS-B', 'zero')       &  0.002 &    16 &   0.013 &   300 &    0.327 &  2853 &    67.109 &  44043 \\
# ('jax', 'none', 'scipy_L-BFGS-B', 'zero')         &  0.003 &    16 &   0.039 &   327 &    0.737 &  3534 &    91.040 &  43627 \\
# ('numba', 'SFD', 'scipy_Newton-CG_hessp', 'zero') &  0.007 &    12 &   0.027 &    17 &    0.551 &    18 &    79.129 &    116 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{lllll}
# \toprule
# {} &  10    &  100   &  1000  &  10000 \\
# \midrule
# ('numba', 'SFD', 'my_trust_region', 'zero')       &  1.030 &  0.651 &  0.764 &  1.018 \\
# ('jax', 'sparse', 'my_trust_region', 'zero')      &  0.242 &  0.269 &  0.307 &  1.279 \\
# ('numba', 'Laplace', 'my_newton', 'zero')         &  0.625 &  0.600 &  0.596 &  0.580 \\
# ('numba', 'SFD', 'my_newton', 'laplace')          &  0.574 &  0.912 &  0.624 &  0.924 \\
# ('jax', 'sparse', 'my_newton', 'laplace')         &  0.263 &  0.258 &  0.303 &  0.639 \\
# ('numpy', 'none', 'scipy_L-BFGS-B', 'zero')       &  0.000 &  0.000 &  0.001 &  0.000 \\
# ('numba', 'none', 'scipy_L-BFGS-B', 'zero')       &  0.624 &  0.594 &  0.559 &  0.566 \\
# ('jax', 'none', 'scipy_L-BFGS-B', 'zero')         &  0.127 &  0.133 &  0.122 &  0.115 \\
# ('numba', 'SFD', 'scipy_Newton-CG_hessp', 'zero') &  0.857 &  0.581 &  0.639 &  0.889 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_23538/4141737154.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(combined_df2.to_latex(escape=False))
# /tmp/ipykernel_23538/4141737154.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(compile_df.to_latex(escape=False))
