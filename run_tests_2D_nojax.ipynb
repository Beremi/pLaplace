# %%
from pLaplace_2D import test_runner_2D

problem_setting = {"p": 3}  # source term, constant 10

# %% [markdown]
# # Results

# %%
sizes = [1,2,3,4,5,6,7]
all_solvers = []

all_solvers.append({"val_grad": "numpy",
                    "hess": "none",
                    "minimizer": ["scipy_L-BFGS-B"],
                    "solver_type": "amg",
                    "initial_guess": "zero",
                    "problem_setting": problem_setting,
                    "sizes": sizes})
all_solvers.append({"val_grad": "numba",
                    "hess": "none",
                    "minimizer": ["scipy_L-BFGS-B"],
                    "solver_type": "amg",
                    "initial_guess": "zero",
                    "problem_setting": problem_setting,
                    "sizes": sizes})
# all_solvers.append({"val_grad": "jax",
#                     "hess": "none",
#                     "minimizer": ["scipy_L-BFGS-B"],
#                     "solver_type": "amg",
#                     "initial_guess": "zero",
#                     "problem_setting": problem_setting,
#                     "sizes": sizes})
all_solvers.append({"val_grad": "numba",
                    "hess": "SFD",
                    "minimizer": ["scipy_Newton-CG_hessp"],
                    "solver_type": "amg",
                    "initial_guess": "zero",
                    "problem_setting": problem_setting,
                    "sizes": sizes})

all_solvers.append({"val_grad": "numba",
                    "hess": "SFD",
                    "minimizer": ["my_trust_region"],
                    "solver_type": "amg",
                    "initial_guess": "rand",
                    "problem_setting": problem_setting,
                    "sizes": sizes})
# all_solvers.append({"val_grad": "jax",
#                     "hess": "sparse",
#                     "minimizer": ["my_trust_region"],
#                     "solver_type": "amg",
#                     "initial_guess": "rand",
#                     "problem_setting": problem_setting,
#                     "sizes": sizes})
all_solvers.append({"val_grad": "numba",
                    "hess": "SFD",
                    "minimizer": ["my_newton"],
                    "solver_type": "amg",
                    "initial_guess": "rand",
                    "problem_setting": problem_setting,
                    "sizes": sizes})
# all_solvers.append({"val_grad": "jax",
#                     "hess": "sparse",
#                     "minimizer": ["my_newton"],
#                     "solver_type": "amg",
#                     "initial_guess": "rand",
#                     "problem_setting": problem_setting,
#                     "sizes": sizes})
all_solvers.append({"val_grad": "numba",
                    "hess": "SFD",
                    "minimizer": ["my_newton"],
                    "solver_type": "amg",
                    "initial_guess": "laplace",
                    "problem_setting": problem_setting,
                    "sizes": sizes})
# all_solvers.append({"val_grad": "jax",
#                     "hess": "sparse",
#                     "minimizer": ["my_newton"],
#                     "solver_type": "amg",
#                     "initial_guess": "laplace",
#                     "problem_setting": problem_setting,
#                     "sizes": sizes})


results = test_runner_2D.test_runner_2D(all_solvers)
iterations_df, f_val_df, compile_df, solve_df, combined_time_df, combined_df, combined_df2 = \
                                test_runner_2D.create_tables(results, display_table="Ipython")
# Out:
# Function value:
#                                                5           33          161    \
# numpy/none/scipy L-BFGS-B/zero/amg        -5.9342512  -7.3411135  -7.7766893
# numba/none/scipy L-BFGS-B/zero/amg        -5.9342512  -7.3411135  -7.7766893
# numba/SFD/scipy Newton-CG hessp/zero/amg  -5.9342512  -7.3411135  -7.7766893
# numba/SFD/my trust region/rand/amg        -5.9342512  -7.3411135  -7.7766893
# numba/SFD/my newton/rand/amg              -5.9342512  -7.3411135  -7.7766893
# numba/SFD/my newton/laplace/amg           -5.9342512  -7.3411135  -7.7766893
#
#                                                705         2945        12033  \
# numpy/none/scipy L-BFGS-B/zero/amg        -7.9050807  -7.9429687  -7.9545636
# numba/none/scipy L-BFGS-B/zero/amg        -7.9050807  -7.9429687  -7.9545636
# numba/SFD/scipy Newton-CG hessp/zero/amg  -7.9050807  -7.9429687  -7.9545636
# numba/SFD/my trust region/rand/amg        -7.9050807  -7.9429687  -7.9545636
# numba/SFD/my newton/rand/amg              -7.9050807  -7.9429687  -7.9545636
# numba/SFD/my newton/laplace/amg           -7.9050807  -7.9429687  -7.9545635
#
#                                                48641
# numpy/none/scipy L-BFGS-B/zero/amg        -7.9582924
# numba/none/scipy L-BFGS-B/zero/amg        -7.9582924
# numba/SFD/scipy Newton-CG hessp/zero/amg  -7.9582924
# numba/SFD/my trust region/rand/amg        -7.9582924
# numba/SFD/my newton/rand/amg              -7.9582924
# numba/SFD/my newton/laplace/amg           -7.9582921
# Time and iters:
# $\mathcal{N}_{dof}$                               $n=5$               $n=33$  \
# Option                                    time prep/sol iters  time prep/sol
# numpy/none/scipy L-BFGS-B/zero/amg        0.000 / 0.001     9  0.000 / 0.001
# numba/none/scipy L-BFGS-B/zero/amg        5.548 / 0.002     9  0.000 / 0.003
# numba/SFD/scipy Newton-CG hessp/zero/amg  0.001 / 0.005     8  0.001 / 0.009
# numba/SFD/my trust region/rand/amg        0.001 / 0.019     7  0.001 / 0.026
# numba/SFD/my newton/rand/amg              0.001 / 0.006     5  0.001 / 0.012
# numba/SFD/my newton/laplace/amg           0.001 / 0.004     3  0.001 / 0.009
#
# $\mathcal{N}_{dof}$                                   $n=161$        \
# Option                                   iters  time prep/sol iters
# numpy/none/scipy L-BFGS-B/zero/amg          17  0.000 / 0.004    45
# numba/none/scipy L-BFGS-B/zero/amg          17  0.000 / 0.007    45
# numba/SFD/scipy Newton-CG hessp/zero/amg    11  0.001 / 0.015    14
# numba/SFD/my trust region/rand/amg           6  0.001 / 0.054     7
# numba/SFD/my newton/rand/amg                 5  0.001 / 0.020     6
# numba/SFD/my newton/laplace/amg              4  0.002 / 0.013     4
#
# $\mathcal{N}_{dof}$                             $n=705$             $n=2945$  \
# Option                                    time prep/sol iters  time prep/sol
# numpy/none/scipy L-BFGS-B/zero/amg        0.000 / 0.018    88  0.001 / 0.149
# numba/none/scipy L-BFGS-B/zero/amg        5.004 / 0.018    88  0.001 / 0.092
# numba/SFD/scipy Newton-CG hessp/zero/amg  0.004 / 0.024    15  0.013 / 0.061
# numba/SFD/my trust region/rand/amg        0.003 / 0.068     8  0.013 / 0.160
# numba/SFD/my newton/rand/amg              0.003 / 0.030     6  0.012 / 0.079
# numba/SFD/my newton/laplace/amg           0.004 / 0.021     4  0.013 / 0.058
#
# $\mathcal{N}_{dof}$                                 $n=12033$        \
# Option                                   iters  time prep/sol iters
# numpy/none/scipy L-BFGS-B/zero/amg         201  0.004 / 1.598   426
# numba/none/scipy L-BFGS-B/zero/amg         206  0.004 / 3.034   420
# numba/SFD/scipy Newton-CG hessp/zero/amg    14  0.051 / 0.384    15
# numba/SFD/my trust region/rand/amg           9  0.051 / 0.498    10
# numba/SFD/my newton/rand/amg                 7  0.049 / 0.339     8
# numba/SFD/my newton/laplace/amg              5  0.049 / 0.250     5
#
# $\mathcal{N}_{dof}$                            $n=48641$
# Option                                     time prep/sol iters
# numpy/none/scipy L-BFGS-B/zero/amg        0.010 / 14.671   937
# numba/none/scipy L-BFGS-B/zero/amg        0.012 / 14.302   912
# numba/SFD/scipy Newton-CG hessp/zero/amg   0.208 / 2.125    17
# numba/SFD/my trust region/rand/amg         0.218 / 2.316    13
# numba/SFD/my newton/rand/amg               0.214 / 1.832     9
# numba/SFD/my newton/laplace/amg            0.209 / 0.657     5

# %%
print(combined_df2.to_latex(escape=False))
print(compile_df.to_latex(escape=False))
# Out:
# \begin{tabular}{lllllllllllllll}
# \toprule
# $|\mathcal{N}_{dof}|$ & \multicolumn{2}{l}{$n=5$} & \multicolumn{2}{l}{$n=33$} & \multicolumn{2}{l}{$n=161$} & \multicolumn{2}{l}{$n=705$} & \multicolumn{2}{l}{$n=2945$} & \multicolumn{2}{l}{$n=12033$} & \multicolumn{2}{l}{$n=48641$} \\
# Option &   time & iters &   time & iters &    time & iters &    time & iters &     time & iters &      time & iters &      time & iters \\
# \midrule
# numpy/none/scipy L-BFGS-B/zero/amg       &  0.001 &     9 &  0.001 &    17 &   0.004 &    45 &   0.018 &    88 &    0.149 &   201 &     1.598 &   426 &    14.671 &   937 \\
# numba/none/scipy L-BFGS-B/zero/amg       &  0.002 &     9 &  0.003 &    17 &   0.007 &    45 &   0.018 &    88 &    0.092 &   206 &     3.034 &   420 &    14.302 &   912 \\
# numba/SFD/scipy Newton-CG hessp/zero/amg &  0.005 &     8 &  0.009 &    11 &   0.015 &    14 &   0.024 &    15 &    0.061 &    14 &     0.384 &    15 &     2.125 &    17 \\
# numba/SFD/my trust region/rand/amg       &  0.019 &     7 &  0.026 &     6 &   0.054 &     7 &   0.068 &     8 &    0.160 &     9 &     0.498 &    10 &     2.316 &    13 \\
# numba/SFD/my newton/rand/amg             &  0.006 &     5 &  0.012 &     5 &   0.020 &     6 &   0.030 &     6 &    0.079 &     7 &     0.339 &     8 &     1.832 &     9 \\
# numba/SFD/my newton/laplace/amg          &  0.004 &     3 &  0.009 &     4 &   0.013 &     4 &   0.021 &     4 &    0.058 &     5 &     0.250 &     5 &     0.657 &     5 \\
# \bottomrule
# \end{tabular}
#
# \begin{tabular}{llllllll}
# \toprule
# {} &  5     &  33    &  161   &  705   &  2945  &  12033 &  48641 \\
# \midrule
# numpy/none/scipy L-BFGS-B/zero/amg       &  0.000 &  0.000 &  0.000 &  0.000 &  0.001 &  0.004 &  0.010 \\
# numba/none/scipy L-BFGS-B/zero/amg       &  5.548 &  0.000 &  0.000 &  5.004 &  0.001 &  0.004 &  0.012 \\
# numba/SFD/scipy Newton-CG hessp/zero/amg &  0.001 &  0.001 &  0.001 &  0.004 &  0.013 &  0.051 &  0.208 \\
# numba/SFD/my trust region/rand/amg       &  0.001 &  0.001 &  0.001 &  0.003 &  0.013 &  0.051 &  0.218 \\
# numba/SFD/my newton/rand/amg             &  0.001 &  0.001 &  0.001 &  0.003 &  0.012 &  0.049 &  0.214 \\
# numba/SFD/my newton/laplace/amg          &  0.001 &  0.001 &  0.002 &  0.004 &  0.013 &  0.049 &  0.209 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_2756185/551063152.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(combined_df2.to_latex(escape=False))
# /tmp/ipykernel_2756185/551063152.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(compile_df.to_latex(escape=False))
